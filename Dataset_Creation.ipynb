# %%
# %pip install torch
# Out:
# Collecting torchNote: you may need to restart the kernel to use updated packages.
#
#   Downloading torch-2.1.2-cp311-cp311-win_amd64.whl (192.3 MB)
#      ------------------------------------ 192.3/192.3 MB 766.4 kB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from torch) (4.9.0)
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ---------------------------------------- 5.7/5.7 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: networkx in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.2)
# Collecting fsspec
#   Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#      -------------------------------------- 169.0/169.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (2.1.3)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ------------------------------------ 536.2/536.2 kB 841.5 kB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, fsspec, filelock, torch
# Successfully installed filelock-3.13.1 fsspec-2023.12.2 mpmath-1.3.0 sympy-1.12 torch-2.1.2
#   WARNING: The script isympy.exe is installed in 'c:\Users\riddhi\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'c:\Users\riddhi\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pathlib import Path
import torch
import numpy as np
import pandas as pd
import imgaug
from imgaug.augmentables.bbs import BoundingBox

# %% [markdown]
# ## DataSet Creation

# %%
class CardiacDataset(torch.utils.data.Dataset):

    def __init__(self, path_to_labels_csv, patients, root_path, augs):
        
        self.labels = pd.read_csv(path_to_labels_csv)
        
        self.patients = np.load(patients)
        self.root_path = Path(root_path)
        self.augment = augs
        
    def  __len__(self):
        """
        Returns the length of the dataset
        """
        return len(self.patients)
        
    def __getitem__(self, idx):
        """
        Returns an image paired with bbox around the heart
        """
        patient = self.patients[idx]
        # Get data according to index
        data = self.labels[self.labels["name"]==patient]
        
        # Get entries of given patient
        # Extract coordinates
        
        x_min = data["x0"].item()
        y_min = data["y0"].item()
        x_max = x_min + data["w"].item()  # get xmax from width
        y_max = y_min + data["h"].item()  # get ymax from height
        bbox = [x_min, y_min, x_max, y_max]


        # Load file and convert to float32
        file_path = self.root_path/patient  # Create the path to the file
        img = np.load(f"{file_path}.npy").astype(np.float32)
        
        
        # Apply imgaug augmentations to image and bounding box
        if self.augment:
            
            bb = BoundingBox(x1=bbox[0], y1=bbox[1], x2=bbox[2], y2=bbox[3])
            
            
            random_seed = torch.randint(0, 1000000, (1,)).item()
            imgaug.seed(random_seed)
            

            img, aug_bbox  = self.augment(image=img, bounding_boxes=bb)
            bbox = aug_bbox[0][0], aug_bbox[0][1], aug_bbox[1][0], aug_bbox[1][1]
            
            
        # Normalize the image according to the values computed in Preprocessing
        img = (img - 0.494) / 0.252

        img = torch.tensor(img).unsqueeze(0)
        bbox = torch.tensor(bbox)
            
        return img, bbox

# %% [markdown]
# ## Validate functionality

# %%
# %pip install imgaug
# Out:
# Requirement already satisfied: imgaug in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (0.4.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: six in c:\users\riddhi\appdata\roaming\python\python311\site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from imgaug) (1.26.2)
# Requirement already satisfied: scipy in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from imgaug) (1.11.4)
# Requirement already satisfied: Pillow in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from imgaug) (10.1.0)
# Requirement already satisfied: matplotlib in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from imgaug) (3.8.2)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from imgaug) (0.22.0)
# Requirement already satisfied: opencv-python in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from imgaug) (4.8.1.78)
# Requirement already satisfied: imageio in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from imgaug) (2.33.0)
# Requirement already satisfied: Shapely in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from imgaug) (2.0.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from scikit-image>=0.14.2->imgaug) (3.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from scikit-image>=0.14.2->imgaug) (2023.12.9)
# Requirement already satisfied: packaging>=21 in c:\users\riddhi\appdata\roaming\python\python311\site-packages (from scikit-image>=0.14.2->imgaug) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from scikit-image>=0.14.2->imgaug) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\riddhi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\riddhi\appdata\roaming\python\python311\site-packages (from matplotlib->imgaug) (2.8.2)

# %%
import imgaug.augmenters as iaa
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
# First create the augmentation object

seq = iaa.Sequential([
            iaa.GammaContrast(),
            iaa.Affine(
                scale=(0.8, 1.2),
                rotate=(-10, 10),
                translate_px=(-10, 10)
            )
        ])

# %%
labels_path = "E:\\Cardiac Detection\\05-Detection\\rsna_heart_detection.csv"
patients_path = "E:\\Cardiac Detection\\05-Detection\\train_subjects.npy"
train_root = "E:\Cardiac Detection\ProcessedHeart/train/"
dataset = CardiacDataset(labels_path, patients_path, train_root, seq)

# %%
img, bbox = dataset[0]

fig, axis = plt.subplots(1, 1)
axis.imshow(img[0], cmap="bone")
rect = patches.Rectangle((bbox[0], bbox[1]), bbox[2]-bbox[0], bbox[3]-bbox[1], edgecolor="r", facecolor="none")
axis.add_patch(rect)

# %%
img, label = dataset[17]

fig, axis = plt.subplots(1, 1)
axis.imshow(img[0], cmap="bone")
spot1 = patches.Rectangle((label[0], label[1]), label[2]-label[0], label[3]-label[1], edgecolor='r', facecolor='none')
axis.add_patch(spot1)

axis.set_title("X-RAY with BBOX around heart")
print(label)
# Out:
# tensor([ 70.4283,  52.7976, 186.5106, 186.6779])
